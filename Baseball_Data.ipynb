# %%
#import dependencies
import requests
import json
import pandas as pd
import pprint
import us
import pymongo
import plotly

# %%
team_stats_url = "https://www.baseball-reference.com/leagues/MLB/2020.shtml"

# %%
#read table from url
tables = pd.read_html(team_stats_url)
team_stats_db = tables[0]
team_stats_db
# Out:
#        Tm  #Bat  BatAge   R/G     G     PA     AB     R      H    2B  ...  \
# 0     ARI    45    29.1  4.48    60   2238   1997   269    482   101  ...
# 1     ATL    48    28.2  5.80    60   2344   2074   348    556   130  ...
# 2     BAL    45    26.3  4.57    60   2242   2026   274    523   102  ...
# 3     BOS    47    27.1  4.87    60   2304   2083   292    552   118  ...
# 4     CHC    47    27.9  4.42    60   2214   1918   265    422    82  ...
# 5     CHW    48    27.6  5.10    60   2267   2047   306    534    94  ...
# 6     CIN    43    29.1  4.05    60   2123   1842   243    390    76  ...
# 7     CLE    39    27.9  4.13    60   2247   1959   248    446    96  ...
# 8     COL    40    28.7  4.58    60   2257   2057   275    528    84  ...
# 9     DET    45    27.5  4.29    58   2076   1893   249    463    78  ...
# 10    HOU    43    29.2  4.65    60   2229   1992   279    478   103  ...
# 11    KCR    48    27.8  4.13    60   2200   1988   248    485    97  ...
# ...

# %%
team_stats_db = team_stats_db.drop([30,31,32])

# %%
import plotly.express as px
# df = px.data.tips()#.query("year == 2007").query("continent == 'Europe'")
# df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries

fig = px.pie(values=hits_list, names=team_list)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-be2488761dc5> in <module>
#       3 # df.loc[df['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
#       4
# ----> 5 fig = px.pie(values=hits_list, names=team_list)
#       6 fig.show()
#
# NameError: name 'hits_list' is not defined

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
import plotly.graph_objects as go
from plotly.offline import iplot, init_notebook_mode

hits_list=team_stats_db['H'].to_list()
team_list=team_stats_db['Tm'].to_list()

fig = go.Figure(
    data=[go.Bar(x=team_list, y=hits_list)],
    layout_title_text="Hits by Team"
)

fig.show()

# app = dash.Dash(__name__)

# app.layout = html.Div([
#     dcc.Graph(id="graph", figure=fig),
# ])

# app.run_server(debug=True)

# %%
import plotly.io as pio
pio.renderers

# %%
pio.renderers.default = "notebook_connected"

# %%
teams = []
team_stats = {'_id': 'team_offense'}

for team in team_stats_db:
    this_state = us.states.lookup(f'{state}')
    this_abbr = this_state.abbr
    abbreviations.append(this_abbr)
    energy_data.update({this_abbr: {'Wind': 0}})

print(abbreviations)


print(energy_data)

# %%
team_stats_db = team_stats_db.set_index('Tm')

team_stats_db
# Out:
#     #Bat BatAge   R/G   G    PA    AB    R    H   2B  3B  ...   SLG   OPS  \
# Tm                                                        ...
# ARI   45   29.1  4.48  60  2238  1997  269  482  101  12  ...  .391  .704
# ATL   48   28.2  5.80  60  2344  2074  348  556  130   3  ...  .483  .832
# BAL   45   26.3  4.57  60  2242  2026  274  523  102   7  ...  .429  .750
# BOS   47   27.1  4.87  60  2304  2083  292  552  118   7  ...  .445  .775
# CHC   47   27.9  4.42  60  2214  1918  265  422   82   8  ...  .387  .705
# CHW   48   27.6  5.10  60  2267  2047  306  534   94   6  ...  .453  .779
# CIN   43   29.1  4.05  60  2123  1842  243  390   76   3  ...  .403  .715
# CLE   39   27.9  4.13  60  2247  1959  248  446   96   5  ...  .372  .689
# COL   40   28.7  4.58  60  2257  2057  275  528   84  16  ...  .405  .716
# DET   45   27.5  4.29  58  2076  1893  249  463   78  12  ...  .397  .700
# HOU   43   29.2  4.65  60  2229  1992  279  478  103  12  ...  .408  .720
# ...

# %%
team_stat_dict = team_stats_db.to_dict('index')

# %%
team_stat_dict
# Out:
# {'ARI': {'#Bat': '45',
#   'BatAge': '29.1',
#   'R/G': '4.48',
#   'G': '60',
#   'PA': '2238',
#   'AB': '1997',
#   'R': '269',
#   'H': '482',
#   '2B': '101',
#   '3B': '12',
#   'HR': '58',
#   'RBI': '255',
#   'SB': '23',
#   'CS': '7',
#   'BB': '181',
#   'SO': '461',
#   'BA': '.241',
#   'OBP': '.312',
#   'SLG': '.391',
#   'OPS': '.704',
#   'OPS+': '87',
#   'TB': '781',
#   'GDP': '37',
#   'HBP': '36',
#   'SH': '1',
#   'SF': '23',
#   'IBB': '5',
#   'LOB': '399'},
#  'ATL': {'#Bat': '48',
#   'BatAge': '28.2',
#   'R/G': '5.80',
#   'G': '60',
#   'PA': '2344',
#   'AB': '2074',
#   'R': '348',
#   'H': '556',
#   '2B': '130',
#   '3B': '3',
#   'HR': '103',
#   'RBI': '338',
#   'SB': '23',
#   'CS': '4',
#   'BB': '239',
#   'SO': '573',
#   'BA': '.268',
#   'OBP': '.349',
#   'SLG': '.483',
#   'OPS': '.832',
#   'OPS+': '116',
#   'TB': '1001',
#   'GDP': '39',
#   'HBP': '23',
#   'SH': '1',
#   'SF': '7',
#   'IBB': '13',
#   'LOB': '437'},
# ...

# %%
client = pymongo.MongoClient('mongodb+srv://rdashcraft91:R4$hcr4ft13@cluster0.7zksg.mongodb.net/test')

# %%
db = client.team_db

# %%
team_stats = db.team_statistics
team_stats.insert_many([team_stat_dict])
